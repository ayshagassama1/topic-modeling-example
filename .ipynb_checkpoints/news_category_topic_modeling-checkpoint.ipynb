# %%
# !pip install pandas
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement json
# ERROR: No matching distribution found for json

# %%
import pandas as pd
import json

# %%
datas = pd.read_json("News_Category_Dataset_v3.json", lines=True)

# %%
datas
# Out:
#                                                    link  \
# 0     https://www.huffpost.com/entry/espresso-martin...
# 1     https://www.huffpost.com/entry/florida-breaks-...
# 2     https://www.huffpost.com/entry/fear-street-pop...
# 3     https://www.huffpost.com/entry/hitler-quote-co...
# 4     https://www.huffpost.com/entry/trump-january-6...
# ...                                                 ...
# 6304  https://www.huffpost.com/entry/us-north-korean...
# 6305  https://www.huffpost.com/entry/subtropical-sto...
# 6306  https://www.huffpost.com/entry/europa-park-fir...
# 6307  https://www.huffpost.com/entry/us-warships-sou...
# 6308  https://www.huffpost.com/entry/lava-flow-power...
#
#                                                headline       category  \
# 0     Espresso Martinis: What To Know About Summer's...   FOOD & DRINK
# 1     Florida Breaks Annual Manatee Death Record In ...    ENVIRONMENT
# 2     The Most Popular Movies On Netflix Right Now B...  HOME & LIVING
# ...

# %%
# !pip install spacy

# %%
import spacy

# %%
from spacy.lang.en import English

nlp = English()
# liste des mots vides en anglais
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# %%
stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %% [markdown]
# On vérifie s'il ya des valeurs manquantes et si oui combien

# %%
datas['short_description'].isnull().sum()
# Out:
# 0
